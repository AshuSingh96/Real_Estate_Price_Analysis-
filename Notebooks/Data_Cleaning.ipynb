# %%
import pandas as pd
import random

# %%
df= pd.read_csv('Downloads/House Price India.csv')

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
unique_postal_codes = df['Postal Code'].unique()

# %%
print(unique_postal_codes)
# Out:
# [122004 122005 122006 122007 122008 122009 122010 122011 122012 122013
#  122014 122015 122016 122017 122018 122019 122020 122021 122022 122023
#  122024 122025 122026 122027 122028 122029 122030 122031 122032 122033
#  122034 122035 122036 122037 122038 122039 122040 122041 122042 122043
#  122044 122045 122046 122047 122048 122049 122003 122050 122051 122052
#  122053 122054 122055 122056 122057 122058 122059 122060 122061 122062
#  122063 122064 122065 122066 122067 122068 122069 122070 122071 122072]

# %%
postal_code_to_city = {
    122004: 'Gurgaon',
    122005: 'Gurgaon',
    122006: 'Gurgaon',
    122007: 'Gurgaon',
    122008: 'Gurgaon',
    122009: 'Gurgaon',
    122010: 'Gurgaon',
    122011: 'Gurgaon',
    122012: 'Gurgaon',
    122013: 'Gurgaon',
    122014: 'Gurgaon',
    122015: 'Gurgaon',
    122016: 'Gurgaon',
    122017: 'Gurgaon',
    122018: 'Gurgaon',
    122019: 'Gurgaon',
    122020: 'Gurgaon',
    122021: 'Gurgaon',
    122022: 'Gurgaon',
    122023: 'Gurgaon',
    122024: 'Gurgaon',
    122025: 'Gurgaon',
    122026: 'Gurgaon',
    122027: 'Gurgaon',
    122028: 'Gurgaon',
    122029: 'Gurgaon',
    122030: 'Gurgaon',
    122031: 'Gurgaon',
    122032: 'Gurgaon',
    122033: 'Gurgaon',
    122034: 'Gurgaon',
    122035: 'Gurgaon',
    122036: 'Gurgaon',
    122037: 'Gurgaon',
    122038: 'Gurgaon',
    122039: 'Gurgaon',
    122040: 'Gurgaon',
    122041: 'Gurgaon',
    122042: 'Gurgaon',
    122043: 'Gurgaon',
    122044: 'Gurgaon',
    122045: 'Gurgaon',
    122046: 'Gurgaon',
    122047: 'Gurgaon',
    122048: 'Gurgaon',
    122049: 'Gurgaon',
    122003: 'Gurgaon',
    122050: 'Gurgaon',
    122051: 'Gurgaon',
    122052: 'Gurgaon',
    122053: 'Gurgaon',
    122054: 'Gurgaon',
    122055: 'Gurgaon',
    122056: 'Gurgaon',
    122057: 'Gurgaon',
    122058: 'Gurgaon',
    122059: 'Gurgaon',
    122060: 'Gurgaon',
    122061: 'Gurgaon',
    122062: 'Gurgaon',
    122063: 'Gurgaon',
    122064: 'Gurgaon',
    122065: 'Gurgaon',
    122066: 'Gurgaon',
    122067: 'Gurgaon',
    122068: 'Gurgaon',
    122069: 'Gurgaon',
    122070: 'Gurgaon',
    122071: 'Gurgaon',
    122072: 'Gurgaon'
}

# %%
df['City'] = df['Postal Code'].map(postal_code_to_city)

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df['Locality'] = df['Postal Code'].map(postal_code_to_city)

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df['Property Type'] = 'Residential'

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
if 'Furnishing Status' not in df.columns:
    df['Furnishing Status'] = None  # You can set this as None initially if required

# Randomly assign "Furnished" or "Unfurnished" to the 'Furnishing Status' column
df['Furnishing Status'] = df['Furnishing Status'].apply(lambda x: random.choice(['Furnished', 'Unfurnished']))

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df['Number of Rooms'] = df['number of bedrooms']
df['Number of Bathrooms'] =df['number of bathrooms']
df['Area (Sq.Ft.)'] = df['living area']  # You can exclude basement area if necessary

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
columns_to_add = ['Balcony', 'Clubhouse', 'Swimming Pool', 'Kids Play Areas', 'Parking']

for column in columns_to_add:
    if column not in df.columns:
        df[column] = df.apply(lambda x: random.choice([0, 1]), axis=1)

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df['Area Type'] = "Living Area"

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df['State'] = "Haryana"

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price',
#        'City', 'Locality', 'Property Type', 'Furnishing Status',
#        'Number of Rooms', 'Number of Bathrooms', 'Area (Sq.Ft.)', 'Balcony',
#        'Clubhouse', 'Swimming Pool', 'Kids Play Areas', 'Parking', 'Area Type',
#        'State'],
#       dtype='object')

# %%
columns_to_keep = [
    'City', 'Locality', 'Property Type', 'Price', 'Furnishing Status', 'Number of Rooms', 
    'Number of Bathrooms', 'Area (Sq.Ft.)', 'Balcony', 'Clubhouse', 'Swimming Pool', 
    'Kids Play Areas', 'Parking', 'Area Type', 'State'
]

# %%
df = df[columns_to_keep]

# %%
df
# Out:
#           City Locality Property Type    Price Furnishing Status  \
# 0      Gurgaon  Gurgaon   Residential  1400000       Unfurnished
# 1      Gurgaon  Gurgaon   Residential  1200000       Unfurnished
# 2      Gurgaon  Gurgaon   Residential   838000         Furnished
# 3      Gurgaon  Gurgaon   Residential   805000         Furnished
# 4      Gurgaon  Gurgaon   Residential   790000       Unfurnished
# ...        ...      ...           ...      ...               ...
# 14614  Gurgaon  Gurgaon   Residential   221700         Furnished
# 14615  Gurgaon  Gurgaon   Residential   219200         Furnished
# 14616  Gurgaon  Gurgaon   Residential   209000       Unfurnished
# 14617  Gurgaon  Gurgaon   Residential   205000         Furnished
# 14618  Gurgaon  Gurgaon   Residential   146000         Furnished
#
#        Number of Rooms  Number of Bathrooms  Area (Sq.Ft.)  Balcony  \
# 0                    4                 2.50           2920        0
# ...

# %%
# Check the shape (rows, columns) of the DataFrame
print(f"Shape of the dataset: {df.shape}")

# Check the data types and basic info
print("\nData Types and Info:")
print(df.info())

# Get basic statistics of numerical columns
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Shape of the dataset: (14619, 15)
#
# Data Types and Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 14619 non-null  object
#  1   Locality             14619 non-null  object
#  2   Property Type        14619 non-null  object
#  3   Price                14619 non-null  int64
#  4   Furnishing Status    14619 non-null  object
#  5   Number of Rooms      14619 non-null  int64
#  6   Number of Bathrooms  14619 non-null  float64
#  7   Area (Sq.Ft.)        14619 non-null  int64
#  8   Balcony              14619 non-null  int64
#  9   Clubhouse            14619 non-null  int64
#  10  Swimming Pool        14619 non-null  int64
#  11  Kids Play Areas      14619 non-null  int64
#  12  Parking              14619 non-null  int64
#  13  Area Type            14619 non-null  object
# ...

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# City                   0
# Locality               0
# Property Type          0
# Price                  0
# Furnishing Status      0
# Number of Rooms        0
# Number of Bathrooms    0
# Area (Sq.Ft.)          0
# Balcony                0
# Clubhouse              0
# Swimming Pool          0
# Kids Play Areas        0
# Parking                0
# Area Type              0
# State                  0
# dtype: int64

# %%
print("\nCategorical Variables Distribution:")
print(df['Property Type'].value_counts())
print(df['Furnishing Status'].value_counts())
print(df['State'].value_counts())
# Out:
# Categorical Variables Distribution:
# Property Type
# Residential    14619
# Name: count, dtype: int64
# Furnishing Status
# Unfurnished    7407
# Furnished      7212
# Name: count, dtype: int64
# State
# Haryana    14619
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Price'])
plt.title('Boxplot for Price')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Area (Sq.Ft.)'])
plt.title('Boxplot for Area (Sq.Ft.)')
plt.show()

# %%
duplicates = df[df.duplicated()]

# Print the number of duplicate rows
print(f"Number of duplicate rows: {duplicates.shape[0]}")
# Out:
# Number of duplicate rows: 4

# %%
df_cleaned = df.drop_duplicates()

# %%
import numpy as np

# Function to remove outliers using IQR
def remove_outliers(df):
    # Loop through each numeric column in the dataframe
    for col in df.select_dtypes(include=[np.number]).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        # Calculate the bounds
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Filter out the outliers
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
        
    return df

# Remove outliers from the dataframe
df_cleaned = remove_outliers(df)

# %%
df_cleaned
# Out:
#           City Locality Property Type   Price Furnishing Status  \
# 2      Gurgaon  Gurgaon   Residential  838000         Furnished
# 3      Gurgaon  Gurgaon   Residential  805000         Furnished
# 4      Gurgaon  Gurgaon   Residential  790000       Unfurnished
# 5      Gurgaon  Gurgaon   Residential  785000         Furnished
# 6      Gurgaon  Gurgaon   Residential  750000         Furnished
# ...        ...      ...           ...     ...               ...
# 14614  Gurgaon  Gurgaon   Residential  221700         Furnished
# 14615  Gurgaon  Gurgaon   Residential  219200         Furnished
# 14616  Gurgaon  Gurgaon   Residential  209000       Unfurnished
# 14617  Gurgaon  Gurgaon   Residential  205000         Furnished
# 14618  Gurgaon  Gurgaon   Residential  146000         Furnished
#
#        Number of Rooms  Number of Bathrooms  Area (Sq.Ft.)  Balcony  \
# 2                    4                 2.50           3310        1
# ...

# %%
df_cleaned.to_csv('Gurgaon_cleaned2.csv', index=False)
