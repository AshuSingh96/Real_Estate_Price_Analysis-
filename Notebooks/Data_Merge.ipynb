# %%
import pandas as pd

# %%
df1 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Ahemdabad_Cleaned.csv')
df2 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Chandigarh_Cleaned.csv')
df3 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Chennai_Cleaned.csv')
df4 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Coimbatore_Cleaned.csv')
df5 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Delhi_Cleaned.csv')
df6 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Hyderabad_Cleaned.csv')
df7 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Jaipur_Cleaned.csv')
df8 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Kolkata_Cleaned.csv')
df9 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Lucknow_Cleaned.csv')
df10 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Mumbai_Cleaned.csv')
df11 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Nagpur_Cleaned.csv')
df12 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Nashik_Cleaned.csv')
df13 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Noida_Cleaned.csv')
df14 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Patna_Cleaned.csv')
df15 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Pune_Cleaned.csv')
df16 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Surat_Cleaned.csv')
df17 = pd.read_csv('Downloads/real estate/Real-Estate-Price-Prediction-Analysis-main (1)/Real-Estate-Price-Prediction-Analysis-main/Datasets/Vijayawada_Cleaned.csv')
df18 = pd.read_csv('BANGALORE_Cleaned.csv')
df19 = pd.read_csv('Gurgaon_cleaned2.csv')

# %%
df1.columns,df2.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'Area Type', 'State'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'Area Type', 'State'],
#        dtype='object'))

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df = df[['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
           'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
           'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
           'State', 'Area Type']]

# %%
df.columns, df3.columns, df4.columns, df5.columns, df6.columns, df7.columns, df8.columns, df9.columns, df10.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
# ...

# %%
df = pd.concat([df, df3,df4,df5,df6,df7,df8,df9,df10], ignore_index=True)

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Chandigarh', 'Tamil Nadu', 'Delhi', 'Telangana',
#        'Rajasthan', 'West Bengal', 'Uttar Pradesh', 'Maharashtra'],
#       dtype=object)

# %%
df.columns, df11.columns, df12.columns, df13.columns, df14.columns, df15.columns, df16.columns, df17.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
# ...

# %%
df = pd.concat([df, df11,df12,df13,df14,df15,df16,df17], ignore_index=True)

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Chandigarh', 'Tamil Nadu', 'Delhi', 'Telangana',
#        'Rajasthan', 'West Bengal', 'Uttar Pradesh', 'Maharashtra',
#        'Bihar', 'Andhra Pradesh'], dtype=object)

# %%
df18.columns, df.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'Area Type', 'State'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'))

# %%
df18.columns = df18.columns.str.replace('Number of Bathrooms', 'Number of Bathroom')
df18.columns = df18.columns.str.replace('Kids Play Areas', '"Kids Play Areas"')

# %%
df18 = df18[['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
           'Number of Rooms', 'Number of Bathrooms', 'Area (Sq.Ft.)', 'Balcony',
           'Clubhouse', 'Swimming Pool', 'Kids Play Areas', 'Parking', 'Area Type', 'State']]

# %%
df.columns , df18.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Area (Sq.Ft.)', 'Balcony',
#         'Clubhouse', 'Swimming Pool', '"Kids Play Areas"', 'Parking',
#         'Area Type', 'State'],
#        dtype='object'))

# %%
column_order = ['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
                'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
                'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
                'State', 'Area Type']

# Reorder the columns of df2
df18 = df18[column_order]

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Chandigarh', 'Tamil Nadu', 'Delhi', 'Telangana',
#        'Rajasthan', 'West Bengal', 'Uttar Pradesh', 'Maharashtra',
#        'Bihar', 'Andhra Pradesh'], dtype=object)

# %%
df = pd.concat([df, df18], ignore_index=True)

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Chandigarh', 'Tamil Nadu', 'Delhi', 'Telangana',
#        'Rajasthan', 'West Bengal', 'Uttar Pradesh', 'Maharashtra',
#        'Bihar', 'Andhra Pradesh', 'Karnatka'], dtype=object)

# %%
df
# Out:
#             City          Locality Property Type         Price  \
# 0      Ahmedabad           Makarba   Residential  1.150000e+07
# 1      Ahmedabad           Makarba   Residential  6.500000e+06
# 2      Ahmedabad        Ambli Road   Residential  7.210000e+07
# 3      Ahmedabad             Shela   Residential  1.300000e+07
# 4      Ahmedabad          Bodakdev   Residential  1.500000e+07
# ...          ...               ...           ...           ...
# 19141  Bangalore       Channohalli          Plot  2.159587e+07
# 19142  Bangalore    Dollars Colony          Plot  2.159587e+07
# 19143  Bangalore        Tata Nagar          Plot  2.159587e+07
# 19144  Bangalore  Doddabommasandra          Plot  2.159587e+07
# 19145  Bangalore      New Bel Road          Plot  2.159587e+07
#
#       Furnishing Status  Number of Rooms  Number of Bathroom        Balcony  \
# 0             Furnished                3                   3     Individual
# ...

# %%
df19.columns, df.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathrooms', 'Area (Sq.Ft.)', 'Balcony',
#         'Clubhouse', 'Swimming Pool', 'Kids Play Areas', 'Parking', 'Area Type',
#         'State'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'))

# %%
df19.columns = df19.columns.str.replace('Number of Bathrooms', 'Number of Bathroom')
df19.columns = df19.columns.str.replace('Kids Play Areas', '"Kids Play Areas"')

# %%
column_order = ['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
                'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
                'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
                'State', 'Area Type']

# Reorder the columns of df2
df19 = df19[column_order]

# %%
df = pd.concat([df, df19], ignore_index=True)

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Chandigarh', 'Tamil Nadu', 'Delhi', 'Telangana',
#        'Rajasthan', 'West Bengal', 'Uttar Pradesh', 'Maharashtra',
#        'Bihar', 'Andhra Pradesh', 'Karnatka', 'Haryana'], dtype=object)

# %%
df
# Out:
#             City    Locality Property Type       Price Furnishing Status  \
# 0      Ahmedabad     Makarba   Residential  11500000.0         Furnished
# 1      Ahmedabad     Makarba   Residential   6500000.0       Unfurnished
# 2      Ahmedabad  Ambli Road   Residential  72100000.0    Semi-Furnished
# 3      Ahmedabad       Shela   Residential  13000000.0       Unfurnished
# 4      Ahmedabad    Bodakdev   Residential  15000000.0         Furnished
# ...          ...         ...           ...         ...               ...
# 32441    Gurgaon     Gurgaon   Residential    221700.0         Furnished
# 32442    Gurgaon     Gurgaon   Residential    219200.0         Furnished
# 32443    Gurgaon     Gurgaon   Residential    209000.0       Unfurnished
# 32444    Gurgaon     Gurgaon   Residential    205000.0         Furnished
# 32445    Gurgaon     Gurgaon   Residential    146000.0         Furnished
#
#        Number of Rooms  Number of Bathroom        Balcony  Clubhouse  \
# ...

# %%
 #Check for duplicates in the merged_cleaned dataframe
duplicates = df[merged_df.duplicated()]

# Print the number of duplicate rows
print(f"Number of duplicate rows: {duplicates.shape[0]}")

# If you want to remove the duplicates and create a cleaned version
cleaned_final = df.drop_duplicates()
# Out:
# Number of duplicate rows: 6

# %%
cleaned_final.to_csv('cleaned_final.csv', index=False)
